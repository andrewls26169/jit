# %%
import csv
import json

# %%
INFILE = "Cosmological argument.csv"
OUTFILE = "hypertree2.js"

# %%
infile = csv.DictReader(open(INFILE))
lines = list(infile)
print(lines)
# Out:
# [{'To': '', 'ID': '1', 'Name': 'Cosmological argument', 'Text': 'The universe needs a first cause, therefore God exists as said first cause.', 'Type': ''}, {'To': '1', 'ID': '2', 'Name': 'Could not exist', 'Text': 'Hypothetically, the universe could not exist, therefore there must be an explaination as to why it exists.', 'Type': 'S'}, {'To': '2', 'ID': '3', 'Name': 'I think therefore I am', 'Text': "I know the universe must exist, otherwise I can't be part of it, therefore it isn't “hypothetically possible” for there to be no universe.", 'Type': 'R'}, {'To': '1', 'ID': '4', 'Name': 'Before the big bang', 'Text': "As the big bang is the start of time itself, to ask what caused it would be like asking “what's north of north?” (as such a cause would be before the biginning of time.", 'Type': 'R'}, {'To': '1', 'ID': '5', 'Name': 'What caused God', 'Text': 'If everything needs a cause, surely God would also need a cause himself. ', 'Type': 'R'}, {'To': '1', 'ID': '6', 'Name': 'Dependance', 'Text': 'All beings are either dependant (have a cause) or independent (no cause). Therefore all beings are dependant OR there is at least one independent being. Not all beings are dependant; therefore there must be an independent being (God).', 'Type': 'S'}, {'To': '6', 'ID': '7', 'Name': 'explaination required', 'Text': 'If all beings are dependant, there must be an explaination for the infinite regression of dependant beings. It also cannot be a part of the chain of dependant beings, so it must be independent', 'Type': 'S'}, {'To': '7', 'ID': '8', 'Name': 'Causal loops', 'Text': "If a being travels back in time, it could be able to cause it's own existance, meaning the “infinite regression” could actually be finite.", 'Type': 'R'}, {'To': '1', 'ID': '9', 'Name': 'Not ontological', 'Text': "The cosmological argument only shows thet there must be an ontological argument to prove God's existence, but said argument isn't showing up anywhere!", 'Type': 'R'}, {'To': '6', 'ID': '10', 'Name': 'A step too far?', 'Text': "An indepenant being does NOT necessarily have to be an omnipotent creator, he/she/it only has to be both immortal and powerful enough to generate a universe; which isn't quite omnipotence as the universe is NOT infinite in size.", 'Type': 'R'}, {'To': '9', 'ID': '11', 'Name': "Not shown isn't nonexistant", 'Text': "Just because the ontological argument we are looking for isn't showing up, doesn't mean it doesn't exist at all. ", 'Type': 'S'}]

# %%
nodes=[]
for line in lines:
    # update edges depending on what's in each node
    node={"id": line["ID"], "name": line["Name"],
         "data": {"text":line["Text"]},
         "adjacencies":[]}
    nodes.append(node)
for line in lines:
    if line["To"]:
        id_from=line["ID"]
        id_to=line["To"]
        for node in nodes:
            if node["id"] == id_to:
                if line["Type"] == 'R':
                    node["adjacencies"].append({"nodeTo":id_from, 
                                                "data":{"weight" : 1, 
                                                        "$color": "#f00"}})
                else:
                    node["adjacencies"].append({"nodeTo":id_from, 
                                                "data":{"weight" : 1}})
            if node["id"] == id_from:
                if line["Type"] == 'R':
                    node["adjacencies"].append({"nodeTo":id_to, 
                                                "data":{"weight" : 1,
                                                        "$color": "#f00"}})
                else:
                    node["adjacencies"].append({"nodeTo":id_to, 
                                                "data":{"weight" : 1}})
                
nodes
# Out:
# [{'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '2'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '4'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '5'},
#    {'data': {'weight': 1}, 'nodeTo': '6'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': 'The universe needs a first cause, therefore God exists as said first cause.'},
#   'id': '1',
#   'name': 'Cosmological argument'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '1'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '3'}],
#   'data': {'text': 'Hypothetically, the universe could not exist, therefore there must be an explaination as to why it exists.'},
#   'id': '2',
#   'name': 'Could not exist'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '2'}],
#   'data': {'text': "I know the universe must exist, otherwise I can't be part of it, therefore it isn't “hypothetically possible” for there to be no universe."},
#   'id': '3',
#   'name': 'I think therefore I am'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '1'}],
#   'data': {'text': "As the big bang is the start of time itself, to ask what caused it would be like asking “what's north of north?” (as such a cause would be before the biginning of time."},
#   'id': '4',
#   'name': 'Before the big bang'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '1'}],
#   'data': {'text': 'If everything needs a cause, surely God would also need a cause himself. '},
#   'id': '5',
#   'name': 'What caused God'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '1'},
#    {'data': {'weight': 1}, 'nodeTo': '7'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '10'}],
#   'data': {'text': 'All beings are either dependant (have a cause) or independent (no cause). Therefore all beings are dependant OR there is at least one independent being. Not all beings are dependant; therefore there must be an independent being (God).'},
#   'id': '6',
#   'name': 'Dependance'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '6'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '8'}],
#   'data': {'text': 'If all beings are dependant, there must be an explaination for the infinite regression of dependant beings. It also cannot be a part of the chain of dependant beings, so it must be independent'},
#   'id': '7',
#   'name': 'explaination required'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '7'}],
#   'data': {'text': "If a being travels back in time, it could be able to cause it's own existance, meaning the “infinite regression” could actually be finite."},
#   'id': '8',
#   'name': 'Causal loops'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '1'},
#    {'data': {'weight': 1}, 'nodeTo': '11'}],
#   'data': {'text': "The cosmological argument only shows thet there must be an ontological argument to prove God's existence, but said argument isn't showing up anywhere!"},
#   'id': '9',
#   'name': 'Not ontological'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '6'}],
#   'data': {'text': "An indepenant being does NOT necessarily have to be an omnipotent creator, he/she/it only has to be both immortal and powerful enough to generate a universe; which isn't quite omnipotence as the universe is NOT infinite in size."},
#   'id': '10',
#   'name': 'A step too far?'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': "Just because the ontological argument we are looking for isn't showing up, doesn't mean it doesn't exist at all. "},
#   'id': '11',
#   'name': "Not shown isn't nonexistant"}]

# %%
print(json.dumps(nodes, indent=4))
# Out:
# [
#     {
#         "name": "Cosmological argument",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "2"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "4"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "5"
#             },
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "6"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ],
#         "data": {
#             "text": "The universe needs a first cause, therefore God exists as said first cause."
#         },
#         "id": "1"
#     },
#     {
#         "name": "Could not exist",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "3"
#             }
#         ],
#         "data": {
#             "text": "Hypothetically, the universe could not exist, therefore there must be an explaination as to why it exists."
#         },
#         "id": "2"
#     },
#     {
#         "name": "I think therefore I am",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "2"
#             }
#         ],
#         "data": {
#             "text": "I know the universe must exist, otherwise I can't be part of it, therefore it isn't \u201chypothetically possible\u201d for there to be no universe."
#         },
#         "id": "3"
#     },
#     {
#         "name": "Before the big bang",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             }
#         ],
#         "data": {
#             "text": "As the big bang is the start of time itself, to ask what caused it would be like asking \u201cwhat's north of north?\u201d (as such a cause would be before the biginning of time."
#         },
#         "id": "4"
#     },
#     {
#         "name": "What caused God",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             }
#         ],
#         "data": {
#             "text": "If everything needs a cause, surely God would also need a cause himself. "
#         },
#         "id": "5"
#     },
#     {
#         "name": "Dependance",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             },
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "7"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "10"
#             }
#         ],
#         "data": {
#             "text": "All beings are either dependant (have a cause) or independent (no cause). Therefore all beings are dependant OR there is at least one independent being. Not all beings are dependant; therefore there must be an independent being (God)."
#         },
#         "id": "6"
#     },
#     {
#         "name": "explaination required",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "6"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "8"
#             }
#         ],
#         "data": {
#             "text": "If all beings are dependant, there must be an explaination for the infinite regression of dependant beings. It also cannot be a part of the chain of dependant beings, so it must be independent"
#         },
#         "id": "7"
#     },
#     {
#         "name": "Causal loops",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "7"
#             }
#         ],
#         "data": {
#             "text": "If a being travels back in time, it could be able to cause it's own existance, meaning the \u201cinfinite regression\u201d could actually be finite."
#         },
#         "id": "8"
#     },
#     {
#         "name": "Not ontological",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             },
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "11"
#             }
#         ],
#         "data": {
#             "text": "The cosmological argument only shows thet there must be an ontological argument to prove God's existence, but said argument isn't showing up anywhere!"
#         },
#         "id": "9"
#     },
#     {
#         "name": "A step too far?",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "6"
#             }
#         ],
#         "data": {
#             "text": "An indepenant being does NOT necessarily have to be an omnipotent creator, he/she/it only has to be both immortal and powerful enough to generate a universe; which isn't quite omnipotence as the universe is NOT infinite in size."
#         },
#         "id": "10"
#     },
#     {
#         "name": "Not shown isn't nonexistant",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ],
#         "data": {
#             "text": "Just because the ontological argument we are looking for isn't showing up, doesn't mean it doesn't exist at all. "
#         },
#         "id": "11"
#     }
# ]

# %%
with open(OUTFILE, 'w') as f:
    with open('hypertree-preamble.txt') as p:
        f.write(p.read())
    json.dump(nodes, f, indent=4) 
    with open('hypertree-postamble.txt') as p:
        f.write(p.read())
