# %%
import csv
import json

# %%
INFILE = "hypertree.csv"
OUTFILE = "hypertree-test.js"

# %%
infile = csv.DictReader(open(INFILE))
lines = list(infile)
print(lines)
# Out:
# [{'Type': 'S', 'Text': 'Scientific theories do not require large assumptions, so they are more reasonable and more likely to be true.', 'ID': '1', 'To': '9', 'Name': 'Most rational explanation'}, {'Type': 'R', 'Text': 'This does not automatically make them true.', 'ID': '2', 'To': '1', 'Name': 'not proof'}, {'Type': 'S', 'Text': 'Science has always had more than its fair share of hate and scrutiny [evidence needed], however they still end up holding water and seeming true-er over time.', 'ID': '3', 'To': '9', 'Name': ' Victorious despite tradition'}, {'Type': 'R', 'Text': 'Physics, by nature, is all about correcting hypotheses, so we never get answers.', 'ID': '4', 'To': '9', 'Name': 'Always correcting itself...'}, {'Type': 'R', 'Text': "Physics FAILS to explain: how the big bang broke the laws of physics, all the totally-not-a-hoax paranormal activity, how a collection of particles (me) can perceive the universe around it, the answer to all the 'why's, or dark matter/energy.", 'ID': '5', 'To': '9', 'Name': "can't explain everything"}, {'Type': 'S', 'Text': 'Experiments often back up scientific theories [evidence needed]', 'ID': '6', 'To': '9', 'Name': 'Empirical evidence'}, {'Type': 'R', 'Text': "many experiments are biased toward the  hypothesis [examples needed], so evidence isn't always reliable", 'ID': '7', 'To': '6', 'Name': 'Bad science'}, {'Type': 'R', 'Text': "Despite science's best efforts, it cannot completely rule out metaphysics, this could show that metaphysics may exist", 'ID': '8', 'To': '9', 'Name': 'no disproof'}, {'Type': '', 'Text': 'There is no metaphysics, just things that can be explained through science rationally', 'ID': '9', 'To': '', 'Name': 'base argument'}]

# %%
nodes=[]
for line in lines:
    # update edges depending on what's in each node
    node={"id": line["ID"], "name": line["Name"],
         "data": {"text":line["Text"]},
         "adjacencies":[]}
    nodes.append(node)
for line in lines:
    if line["To"]:
        id_from=line["ID"]
        id_to=line["To"]
        for node in nodes:
            if node["id"] == id_to:
                if line["Type"] == 'R':
                    node["adjacencies"].append({"nodeTo":id_from, 
                                                "data":{"weight" : 1, 
                                                        "$color": "#f00"}})
                else:
                    node["adjacencies"].append({"nodeTo":id_from, 
                                                "data":{"weight" : 1}})
            if node["id"] == id_from:
                if line["Type"] == 'R':
                    node["adjacencies"].append({"nodeTo":id_to, 
                                                "data":{"weight" : 1,
                                                        "$color": "#f00"}})
                else:
                    node["adjacencies"].append({"nodeTo":id_to, 
                                                "data":{"weight" : 1}})
                
nodes
# Out:
# [{'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '9'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '2'}],
#   'data': {'text': 'Scientific theories do not require large assumptions, so they are more reasonable and more likely to be true.'},
#   'id': '1',
#   'name': 'Most rational explanation'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '1'}],
#   'data': {'text': 'This does not automatically make them true.'},
#   'id': '2',
#   'name': 'not proof'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': 'Science has always had more than its fair share of hate and scrutiny [evidence needed], however they still end up holding water and seeming true-er over time.'},
#   'id': '3',
#   'name': ' Victorious despite tradition'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': 'Physics, by nature, is all about correcting hypotheses, so we never get answers.'},
#   'id': '4',
#   'name': 'Always correcting itself...'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': "Physics FAILS to explain: how the big bang broke the laws of physics, all the totally-not-a-hoax paranormal activity, how a collection of particles (me) can perceive the universe around it, the answer to all the 'why's, or dark matter/energy."},
#   'id': '5',
#   'name': "can't explain everything"},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '9'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '7'}],
#   'data': {'text': 'Experiments often back up scientific theories [evidence needed]'},
#   'id': '6',
#   'name': 'Empirical evidence'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '6'}],
#   'data': {'text': "many experiments are biased toward the  hypothesis [examples needed], so evidence isn't always reliable"},
#   'id': '7',
#   'name': 'Bad science'},
#  {'adjacencies': [{'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '9'}],
#   'data': {'text': "Despite science's best efforts, it cannot completely rule out metaphysics, this could show that metaphysics may exist"},
#   'id': '8',
#   'name': 'no disproof'},
#  {'adjacencies': [{'data': {'weight': 1}, 'nodeTo': '1'},
#    {'data': {'weight': 1}, 'nodeTo': '3'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '4'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '5'},
#    {'data': {'weight': 1}, 'nodeTo': '6'},
#    {'data': {'$color': '#f00', 'weight': 1}, 'nodeTo': '8'}],
#   'data': {'text': 'There is no metaphysics, just things that can be explained through science rationally'},
#   'id': '9',
#   'name': 'base argument'}]

# %%
print(json.dumps(nodes, indent=4))
# Out:
# [
#     {
#         "name": "Most rational explanation",
#         "data": {
#             "text": "Scientific theories do not require large assumptions, so they are more reasonable and more likely to be true."
#         },
#         "id": "1",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "2"
#             }
#         ]
#     },
#     {
#         "name": "not proof",
#         "data": {
#             "text": "This does not automatically make them true."
#         },
#         "id": "2",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             }
#         ]
#     },
#     {
#         "name": " Victorious despite tradition",
#         "data": {
#             "text": "Science has always had more than its fair share of hate and scrutiny [evidence needed], however they still end up holding water and seeming true-er over time."
#         },
#         "id": "3",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ]
#     },
#     {
#         "name": "Always correcting itself...",
#         "data": {
#             "text": "Physics, by nature, is all about correcting hypotheses, so we never get answers."
#         },
#         "id": "4",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ]
#     },
#     {
#         "name": "can't explain everything",
#         "data": {
#             "text": "Physics FAILS to explain: how the big bang broke the laws of physics, all the totally-not-a-hoax paranormal activity, how a collection of particles (me) can perceive the universe around it, the answer to all the 'why's, or dark matter/energy."
#         },
#         "id": "5",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ]
#     },
#     {
#         "name": "Empirical evidence",
#         "data": {
#             "text": "Experiments often back up scientific theories [evidence needed]"
#         },
#         "id": "6",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "7"
#             }
#         ]
#     },
#     {
#         "name": "Bad science",
#         "data": {
#             "text": "many experiments are biased toward the  hypothesis [examples needed], so evidence isn't always reliable"
#         },
#         "id": "7",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "6"
#             }
#         ]
#     },
#     {
#         "name": "no disproof",
#         "data": {
#             "text": "Despite science's best efforts, it cannot completely rule out metaphysics, this could show that metaphysics may exist"
#         },
#         "id": "8",
#         "adjacencies": [
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "9"
#             }
#         ]
#     },
#     {
#         "name": "base argument",
#         "data": {
#             "text": "There is no metaphysics, just things that can be explained through science rationally"
#         },
#         "id": "9",
#         "adjacencies": [
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "1"
#             },
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "3"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "4"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "5"
#             },
#             {
#                 "data": {
#                     "weight": 1
#                 },
#                 "nodeTo": "6"
#             },
#             {
#                 "data": {
#                     "$color": "#f00",
#                     "weight": 1
#                 },
#                 "nodeTo": "8"
#             }
#         ]
#     }
# ]

# %%
with open(OUTFILE, 'w') as f:
    with open('hypertree-preamble.txt') as p:
        f.write(p.read())
    json.dump(nodes, f, indent=4) 
    with open('hypertree-postamble.txt') as p:
        f.write(p.read())
